# %%
# automatically update imports
# %load_ext autoreload
# %autoreload 2

# For graphs
# %matplotlib inline

# snippet for relative imports
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from analysis import Analysis
import ieee_bigdata

grid_step = 100

# %%
#atlanta_georgia_bbox = [ 33.5, -85, 34.45, -83.75 ]
#miami_bbox = [ 25.5, -80.5, 26.85, -80.05 ]

#ieee_bigdata.processCompleteCity('miami_florida', grid_step, [0.1,0.1], bbox = miami_bbox)

# %%
city_ref = 'grenoble_france'
ieee_bigdata.processCompleteCity(city_ref, grid_step, [0.1,0.1], fig_size = (12,8), bubble_plot_step=250 )
# Out:
# ('Bounding box:', [45.113017726416615, 5.573125356566398, 45.243980680751875, 5.9029513504478865])
# Querying locally for `['pois']`
# Found ['pois'] stored locally
# Time POIs: --- 0.00106250047684 minutes ---
# ('POIS: Activities', 11258)
# ('POIS: Residential', 84445)
# ('POIS: Total', 95703)
# Querying locally for `['activity_100', 'residential_100', 'total_100']`
# Found ['activity_100', 'residential_100', 'total_100'] stored locally
# Time KDE's: --- 0.000552050272624 minutes ---
# Time LU Mix grid: --- 0.00549920002619 minutes ---
# Querying locally for `['activity_250', 'residential_250', 'total_250']`
# Found ['activity_250', 'residential_250', 'total_250'] stored locally
# Time KDE's: --- 0.000491718451182 minutes ---
# Time LU Mix grid: --- 0.00113769769669 minutes ---

# %%
city_ref = 'london_england_bbox'
london_bbox = [ 51.32, -0.3, 51.65, 0.05 ]
ieee_bigdata.processCompleteCity(city_ref, grid_step, [0.05,0.05], bbox = london_bbox, fig_size = (12,8), bubble_plot_step=500 )
# Out:
# ('Bounding box:', [50.94102733333333, -1.1148354673036838, 51.98398552604298, 0.8949693])
# Querying locally for `['pois']`
# `['pois']` is/are not stored locally. Determining it/them through `get_extracted_osm_points` method
# Saving data for `['pois']` at `/home/lgervasoni/urban/urban_analysis/hdfs_store/london_england_bbox.h5`
# The data has been stored locally with success
# Time POIs: --- 0.410153480371 minutes ---
# ('POIS: Activities', 65852)
# ('POIS: Residential', 188296)
# ('POIS: Total', 254148)
# Querying locally for `['activity_100', 'residential_100', 'total_100']`
# `['activity_100', 'residential_100', 'total_100']` is/are not stored locally. Determining it/them through `get_grid_all_kde` method
# Saving data for `['activity_100', 'residential_100', 'total_100']` at `/home/lgervasoni/urban/urban_analysis/hdfs_store/london_england_bbox.h5`
# The data has been stored locally with success
# Time KDE's: --- 197.508185518 minutes ---
# ...
