# %%
# automatically update imports
# %load_ext autoreload
# %autoreload 2

# For graphs
# %matplotlib inline

# snippet for relative imports
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from analysis import Analysis

avila = Analysis('avila_spain', pois_shp_path = "cities/avila_spain/full_uses.shp")
chandigarh = Analysis('chandigarh_india', pois_shp_path = "cities/chandigarh_india/full_uses.shp")
dresden = Analysis('dresden_germany', pois_shp_path = "cities/dresden_germany/full_uses.shp")
grenoble = Analysis('grenoble_france', pois_shp_path = "cities/grenoble_france/full_uses.shp")
raleigh = Analysis('raleigh_north-carolina', pois_shp_path = "cities/raleigh_north-carolina/full_uses.shp")
# Out:
# ('Bounding box:', [40.62743561185206, -4.737151721737033, 40.67607507964895, -4.647455953449498])
# ('Bounding box:', [30.619908486247496, 76.6184599, 30.7775464, 76.90148712478653])
# ('Bounding box:', [50.9780205, 13.58603785762049, 51.17996813384094, 13.971962600000001])
# ('Bounding box:', [45.113017726416615, 5.573125356566398, 45.243980680751875, 5.9029513504478865])
# ('Bounding box:', [35.7590107, -79.11595072949167, 36.050888099999995, -78.57705101411202])

# %%
avila.scatter_pois()
print(avila.dissimilarity, avila.kde_dissimilarity)
# Out:
# Saving data for `['activity_0_0015', 'residential_0_0015']` at `/home/martibosch/urbansprawl/urban_analysis/hdfs_store/avila_spain.h5`
# The data has been stored locally with success
# (0.73020979020979071, 0.42845920331620729)
# Querying locally for `['activity_0_0015', 'residential_0_0015']`
# `['activity_0_0015', 'residential_0_0015']` is/are not stored locally. Determining it/them through `get_grid_all_kde` method
# Querying locally for `['pois']`
# Found ['pois'] stored locally

# %%
chandigarh.scatter_pois()
print(chandigarh.dissimilarity, chandigarh.kde_dissimilarity)
# Out:
# Saving data for `['activity_0_0015', 'residential_0_0015']` at `/home/martibosch/urbansprawl/urban_analysis/hdfs_store/chandigarh_india.h5`
# The data has been stored locally with success
# (0.9620014354701778, 0.6826841344083675)
# Querying locally for `['activity_0_0015', 'residential_0_0015']`
# `['activity_0_0015', 'residential_0_0015']` is/are not stored locally. Determining it/them through `get_grid_all_kde` method
# Querying locally for `['pois']`
# Found ['pois'] stored locally

# %%
dresden.scatter_pois()
print(dresden.dissimilarity, dresden.kde_dissimilarity)
# Out:
# Querying locally for `['activity_0_0015', 'residential_0_0015']`
# Found ['activity_0_0015', 'residential_0_0015'] stored locally
# (0.63746410312771051, 0.30287610264675063)

# %%
grenoble.scatter_pois()
print(grenoble.dissimilarity, grenoble.kde_dissimilarity)
# Out:
# Saving data for `['activity_0_0015', 'residential_0_0015']` at `/home/martibosch/urbansprawl/urban_analysis/hdfs_store/grenoble_france.h5`
# The data has been stored locally with success
# (0.77253377689004932, 0.40871375138449439)
# Querying locally for `['activity_0_0015', 'residential_0_0015']`
# `['activity_0_0015', 'residential_0_0015']` is/are not stored locally. Determining it/them through `get_grid_all_kde` method
# Querying locally for `['pois']`
# Found ['pois'] stored locally

# %%
raleigh.scatter_pois()
print(raleigh.dissimilarity, raleigh.kde_dissimilarity)
# Out:
# (0.95200027141062171, 0.3454145788183754)
# Saving data for `['activity_0_0015', 'residential_0_0015']` at `/home/martibosch/urbansprawl/urban_analysis/hdfs_store/raleigh_north-carolina.h5`
# The data has been stored locally with success
# Querying locally for `['activity_0_0015', 'residential_0_0015']`
# `['activity_0_0015', 'residential_0_0015']` is/are not stored locally. Determining it/them through `get_grid_all_kde` method
# Querying locally for `['pois']`
# Found ['pois'] stored locally
