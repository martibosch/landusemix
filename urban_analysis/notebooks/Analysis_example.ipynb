# %%
# automatically update imports
# %load_ext autoreload
# %autoreload 2

# For graphs
# %matplotlib inline

# snippet for relative imports
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from analysis import Analysis
import plot_analysis

grid_step = 100

# %%
city_ref = 'grenoble_france'
plot_analysis.processCompleteCity(city_ref, grid_step, [0.1,0.1], fig_size = (12,8), bubble_plot_step=250 )
# Out:
# ('Bounding box:', [45.113017726416615, 5.573125356566398, 45.243980680751875, 5.9029513504478865])
# Querying locally for `['pois']`
# Found ['pois'] stored locally
# Time POIs: --- 0.00180736780167 minutes ---
# ('POIS: Activities', 11258)
# ('POIS: Residential', 84445)
# ('POIS: Total', 95703)
# Querying locally for `['activity_100', 'residential_100', 'total_100']`
# Found ['activity_100', 'residential_100', 'total_100'] stored locally
# Time KDE's: --- 0.000560784339905 minutes ---
# Time LU Mix grid: --- 0.00577243566513 minutes ---
# Querying locally for `['activity_250', 'residential_250', 'total_250']`
# Found ['activity_250', 'residential_250', 'total_250'] stored locally
# Time KDE's: --- 0.000569633642832 minutes ---
# Time LU Mix grid: --- 0.00118146737417 minutes ---

# %%
city_ref = 'london_england'
# We reduce the region of interest given the following bounding box:
london_bbox = [ 51.32, -0.3, 51.65, 0.05 ]

# Process city
plot_analysis.processCompleteCity(city_ref, grid_step, [0.05,0.05], bbox = london_bbox, fig_size = (12,8), bubble_plot_step=500 )
# Out:
# ('Bounding box:', [50.94102733333333, -1.114835567303684, 51.98398552604297, 0.8949693])
# Querying locally for `['pois']`
# Found ['pois'] stored locally
# Time POIs: --- 0.00692400137583 minutes ---
# ('POIS: Activities', 65852)
# ('POIS: Residential', 188296)
# ('POIS: Total', 254148)
# Querying locally for `['activity_100', 'residential_100', 'total_100']`
# Found ['activity_100', 'residential_100', 'total_100'] stored locally
# Time KDE's: --- 0.000596300760905 minutes ---
# Time LU Mix grid: --- 0.0136678814888 minutes ---
# Querying locally for `['activity_500', 'residential_500', 'total_500']`
# Found ['activity_500', 'residential_500', 'total_500'] stored locally
# Time KDE's: --- 0.000519033273061 minutes ---
# Time LU Mix grid: --- 0.000684666633606 minutes ---
